# %%
import pandas
import matplotlib.pyplot as plt
data = pandas.read_csv("reviews.csv", parse_dates = ['Timestamp']) #telling the dataframe to treat the date as date(int) format and not string 
from datetime import datetime
import matplotlib.pyplot
from pytz import utc

data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %% [markdown]
# ### Rating average/count by day

# %%
data['Day'] = data['Timestamp'].dt.date #It is for extracting the date only b
data.head()

day_average = data.groupby(["Day"]).count()
day_average
# Out:
#             Course Name  Timestamp  Rating  Comment
# Day
# 2018-01-01           46         46      46        7
# 2018-01-02           57         57      57       16
# 2018-01-03           43         43      43        8
# 2018-01-04           48         48      48       11
# 2018-01-05           52         52      52       15
# ...                 ...        ...     ...      ...
# 2021-03-29           25         25      25        1
# 2021-03-30           35         35      35        1
# 2021-03-31           32         32      32        3
# 2021-04-01           27         27      27        3
# 2021-04-02            7          7       7        0
#
# [1188 rows x 4 columns]

# %%
plt.figure(figsize = (25,3))
plt.plot(day_average.index, day_average['Rating'])

# %% [raw]
# day_average['Rating'].max()

# %%
day_average['Rating'].max()
# Out:
# 100

# %%
day_average['Rating'].min()
# Out:
# 7

# %% [markdown]
# ### Rating average/count by week

# %%
data['Week'] = data['Timestamp'].dt.isocalendar().week # as mentioned in the warning when .week() was used 
data['Week'] = data['Timestamp'].dt.strftime('%Y - %U') # use %Y for the year , %m for the month 
data['Week']
# Out:
# 0        2021 - 13
# 1        2021 - 13
# 2        2021 - 13
# 3        2021 - 13
# 4        2021 - 13
#            ...
# 44995    2018 - 00
# 44996    2018 - 00
# 44997    2018 - 00
# 44998    2018 - 00
# 44999    2018 - 00
# Name: Week, Length: 45000, dtype: object

# %%
data
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment       Week
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021 - 13
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021 - 13
# 2     2021-04-02 05:11:03+00:00     4.0     NaN  2021 - 13
# 3     2021-04-02 03:33:24+00:00     5.0     NaN  2021 - 13
# 4     2021-04-02 03:31:49+00:00     4.5     NaN  2021 - 13
# ...                         ...     ...     ...        ...
# 44995 2018-01-01 01:11:26+00:00     4.0     NaN  2018 - 00
# 44996 2018-01-01 01:09:56+00:00     5.0     NaN  2018 - 00
# 44997 2018-01-01 01:08:11+00:00     5.0     NaN  2018 - 00
# 44998 2018-01-01 01:05:26+00:00     5.0     NaN  2018 - 00
# 44999 2018-01-01 01:01:16+00:00     5.0     NaN  2018 - 00
#
# [45000 rows x 5 columns]

# %%
week_average = data.groupby(['Week']).mean()
week_average.head()

plt.figure(figsize = (25,3)) # This determines the sizing of the graph 
plt.plot(week_average.index, week_average['Rating'])

# %% [markdown]
# ### Average rating by month

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y - %m')
mon_average = data.groupby(['Month']).mean()
mon_average.head()
# Out:
#              Rating
# Month
# 2018 - 01  4.429645
# 2018 - 02  4.436248
# 2018 - 03  4.421671
# 2018 - 04  4.468211
# 2018 - 05  4.396420

# %%
data
plt.figure(figsize = (25,3))
plt.plot(mon_average.index,mon_average['Rating'])

# %%
data_services = data.groupby(['Month']).mean()
data_services
# Out:
#          Rating
# Month
# 1      4.453599
# 2      4.446124
# 3      4.457982
# 4      4.462990
# 5      4.424012
# 6      4.426253
# 7      4.441071
# 8      4.413725
# 9      4.426094
# 10     4.458724
# 11     4.446036
# 12     4.444563

# %% [markdown]
# ### Average rating by month by course

# %%
data['Month'] = data['Timestamp'].dt.strftime("%Y - %U")

# %%
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment       Week      Month
# 0 2021-04-02 06:25:52+00:00     4.0     NaN  2021 - 13  2021 - 13
# 1 2021-04-02 05:12:34+00:00     4.0     NaN  2021 - 13  2021 - 13
# 2 2021-04-02 05:11:03+00:00     4.0     NaN  2021 - 13  2021 - 13
# 3 2021-04-02 03:33:24+00:00     5.0     NaN  2021 - 13  2021 - 13
# 4 2021-04-02 03:31:49+00:00     4.5     NaN  2021 - 13  2021 - 13

# %%
mon_average_crs = data.groupby(['Month','Course Name']).mean().unstack() # unstack is used for better presentation of the data 
mon_average_crs
mon_average_crs[:20]
# Out:
#                                                               Rating  \
# Course Name 100 Python Exercises I: Evaluate and Improve Your Skills
# Month
# 2018 - 01                                             4.353448
# 2018 - 02                                             4.250000
# 2018 - 03                                             4.500000
# 2018 - 04                                             4.431034
# 2018 - 05                                             4.358696
# 2018 - 06                                             4.268293
# 2018 - 07                                             4.589286
# 2018 - 08                                             4.353659
# 2018 - 09                                             4.238636
# 2018 - 10                                             4.106061
# 2018 - 11                                             4.212766
# 2018 - 12                                             4.405172
# 2019 - 01                                             4.048780
# 2019 - 02                                             4.333333
# 2019 - 03                                             4.269231
# 2019 - 04                                             4.365854
# 2019 - 05                                             4.486111
# 2019 - 06                                             4.442308
# 2019 - 07                                             4.414634
# 2019 - 08                                             4.222222
#
#                                                                        \
# Course Name 100 Python Exercises II: Evaluate and Improve Your Skills
# Month
# 2018 - 01                                                  NaN
# 2018 - 02                                                  NaN
# 2018 - 03                                                  NaN
# 2018 - 04                                                  NaN
# 2018 - 05                                                  NaN
# 2018 - 06                                                  NaN
# 2018 - 07                                                  NaN
# 2018 - 08                                                  NaN
# 2018 - 09                                                  NaN
# 2018 - 10                                                  NaN
# 2018 - 11                                                  NaN
# 2018 - 12                                                  NaN
# 2019 - 01                                                  NaN
# 2019 - 02                                                  NaN
# 2019 - 03                                                  NaN
# 2019 - 04                                                  NaN
# 2019 - 05                                                  NaN
# 2019 - 06                                             4.722222
# 2019 - 07                                             4.427273
# 2019 - 08                                             4.416667
#
#                                          \
# Course Name Data Processing with Python
# Month
# 2018 - 01                      4.500000
# 2018 - 02                      4.205882
# 2018 - 03                      4.281250
# 2018 - 04                      4.468750
# 2018 - 05                      4.176471
# 2018 - 06                      4.631579
# 2018 - 07                      4.159091
# 2018 - 08                      4.411765
# 2018 - 09                      4.173913
# 2018 - 10                      4.464286
# 2018 - 11                      4.462963
# 2018 - 12                      3.985294
# 2019 - 01                      4.033333
# 2019 - 02                      4.300000
# 2019 - 03                      4.055556
# 2019 - 04                      3.812500
# 2019 - 05                      4.125000
# 2019 - 06                      4.088235
# 2019 - 07                      4.225000
# 2019 - 08                      4.600000
#
#                                                                   \
# Course Name Interactive Data Visualization with Python and Bokeh
# Month
# 2018 - 01                                             4.285714
# 2018 - 02                                             4.157895
# 2018 - 03                                             4.266667
# 2018 - 04                                             4.428571
# 2018 - 05                                             4.107143
# 2018 - 06                                             4.204545
# 2018 - 07                                             4.065217
# 2018 - 08                                             4.233333
# 2018 - 09                                             4.500000
# 2018 - 10                                             4.218750
# 2018 - 11                                             4.113636
# 2018 - 12                                             4.238095
# 2019 - 01                                             4.214286
# 2019 - 02                                             4.285714
# 2019 - 03                                             4.230769
# 2019 - 04                                             4.166667
# 2019 - 05                                             4.236842
# 2019 - 06                                             4.666667
# 2019 - 07                                             4.500000
# 2019 - 08                                             3.789474
#
#                                                                       \
# Course Name Learn GIS in One Hour Python for Beginners with Examples
# Month
# 2018 - 01                4.236842                           4.355422
# 2018 - 02                4.437500                           4.363095
# 2018 - 03                4.166667                           4.357143
# 2018 - 04                4.250000                           4.378947
# 2018 - 05                4.666667                           4.362654
# 2018 - 06                4.333333                           4.273876
# 2018 - 07                4.277778                           4.330239
# 2018 - 08                4.100000                           4.283388
# 2018 - 09                4.166667                           4.247967
# 2018 - 10                4.227273                           4.259259
# 2018 - 11                3.833333                           4.310484
# 2018 - 12                3.925000                           4.336634
# 2019 - 01                4.147059                           4.296992
# 2019 - 02                4.166667                           4.155172
# 2019 - 03                3.875000                           4.188172
# 2019 - 04                3.437500                           4.306122
# 2019 - 05                4.454545                           4.326667
# 2019 - 06                4.416667                           4.057292
# 2019 - 07                4.136364                           4.087838
# 2019 - 08                4.181818                           4.077465
#
#                                                                         \
# Course Name The Complete Python Course: Build 10 Professional OOP Apps
# Month
# 2018 - 01                                                  NaN
# 2018 - 02                                                  NaN
# 2018 - 03                                                  NaN
# 2018 - 04                                                  NaN
# 2018 - 05                                                  NaN
# 2018 - 06                                                  NaN
# 2018 - 07                                                  NaN
# 2018 - 08                                                  NaN
# 2018 - 09                                                  NaN
# 2018 - 10                                                  NaN
# 2018 - 11                                                  NaN
# 2018 - 12                                                  NaN
# 2019 - 01                                                  NaN
# 2019 - 02                                                  NaN
# 2019 - 03                                                  NaN
# 2019 - 04                                                  NaN
# 2019 - 05                                                  NaN
# 2019 - 06                                                  NaN
# 2019 - 07                                                  NaN
# 2019 - 08                                                  NaN
#
#
# Course Name The Python Mega Course: Build 10 Real World Applications
# Month
# 2018 - 01                                             4.457368
# 2018 - 02                                             4.481070
# 2018 - 03                                             4.447037
# 2018 - 04                                             4.507412
# 2018 - 05                                             4.422085
# 2018 - 06                                             4.421264
# 2018 - 07                                             4.436156
# 2018 - 08                                             4.376494
# 2018 - 09                                             4.416413
# 2018 - 10                                             4.415292
# 2018 - 11                                             4.417481
# 2018 - 12                                             4.364149
# 2019 - 01                                             4.443763
# 2019 - 02                                             4.378671
# 2019 - 03                                             4.370213
# 2019 - 04                                             4.474803
# 2019 - 05                                             4.420777
# 2019 - 06                                             4.439291
# 2019 - 07                                             4.412245
# 2019 - 08                                             4.465208
