# %%
import pandas
import matplotlib.pyplot as plt
data = pandas.read_csv("reviews.csv", parse_dates = ['Timestamp']) #telling the dataframe to treat the date as date(int) format and not string 
from datetime import datetime
import matplotlib.pyplot
from pytz import utc

data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %% [markdown]
# ### Rating average/count by day

# %%
data['Day'] = data['Timestamp'].dt.date #It is for extracting the date only b
data.head()

day_average = data.groupby(["Day"]).count()
day_average
# Out:
#             Course Name  Timestamp  Rating  Comment
# Day
# 2018-01-01           46         46      46        7
# 2018-01-02           57         57      57       16
# 2018-01-03           43         43      43        8
# 2018-01-04           48         48      48       11
# 2018-01-05           52         52      52       15
# ...                 ...        ...     ...      ...
# 2021-03-29           25         25      25        1
# 2021-03-30           35         35      35        1
# 2021-03-31           32         32      32        3
# 2021-04-01           27         27      27        3
# 2021-04-02            7          7       7        0
#
# [1188 rows x 4 columns]

# %%
plt.figure(figsize = (25,3))
plt.plot(day_average.index, day_average['Rating'])

# %% [raw]
# day_average['Rating'].max()

# %%
day_average['Rating'].max()
# Out:
# 100

# %%
day_average['Rating'].min()
# Out:
# 7

# %% [markdown]
# ### Rating average/count by week

# %%
data['Week'] = data['Timestamp'].dt.isocalendar().week # as mentioned in the warning when .week() was used 
data['Week'] = data['Timestamp'].dt.strftime('%Y - %U') # use %Y for the year , %m for the month 
data['Week']
# Out:
# 0        2021 - 13
# 1        2021 - 13
# 2        2021 - 13
# 3        2021 - 13
# 4        2021 - 13
#            ...
# 44995    2018 - 00
# 44996    2018 - 00
# 44997    2018 - 00
# 44998    2018 - 00
# 44999    2018 - 00
# Name: Week, Length: 45000, dtype: object

# %%
data
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day       Week
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 - 13
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 - 13
# ...

# %%
week_average = data.groupby(['Week']).mean()
week_average.head()

plt.figure(figsize = (25,3)) # This determines the sizing of the graph 
plt.plot(week_average.index, week_average['Rating'])

# %% [markdown]
# ### Average rating by month

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y - %m')
mon_average = data.groupby(['Month']).mean()
mon_average.head()
# Out:
#              Rating
# Month
# 2018 - 01  4.429645
# 2018 - 02  4.436248
# 2018 - 03  4.421671
# 2018 - 04  4.468211
# 2018 - 05  4.396420

# %%
data
plt.figure(figsize = (25,3))
plt.plot(mon_average.index,mon_average['Rating'])

# %%
data_services = data.groupby(['Month']).mean()
data_services
# Out:
#              Rating
# Month
# 2018 - 01  4.429645
# 2018 - 02  4.436248
# 2018 - 03  4.421671
# 2018 - 04  4.468211
# 2018 - 05  4.396420
# 2018 - 06  4.375379
# 2018 - 07  4.393184
# 2018 - 08  4.344753
# 2018 - 09  4.347247
# 2018 - 10  4.374429
# 2018 - 11  4.386817
# 2018 - 12  4.342105
# 2019 - 01  4.401920
# 2019 - 02  4.346964
# 2019 - 03  4.333145
# 2019 - 04  4.420049
# 2019 - 05  4.405569
# 2019 - 06  4.398559
# 2019 - 07  4.382353
# 2019 - 08  4.417059
# 2019 - 09  4.451135
# 2019 - 10  4.483871
# 2019 - 11  4.493260
# 2019 - 12  4.471046
# 2020 - 01  4.439615
# 2020 - 02  4.428642
# 2020 - 03  4.480690
# 2020 - 04  4.475220
# 2020 - 05  4.448082
# 2020 - 06  4.482812
# 2020 - 07  4.517508
# 2020 - 08  4.470987
# 2020 - 09  4.485862
# 2020 - 10  4.515201
# 2020 - 11  4.479306
# 2020 - 12  4.528358
# 2021 - 01  4.551325
# 2021 - 02  4.567901
# 2021 - 03  4.589207
# 2021 - 04  4.544118

# %% [markdown]
# ### Average rating by month by course

# %%
data['Month'] = data['Timestamp'].dt.strftime("%Y - %U")

# %%
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment         Day       Week      Month
# 0 2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 - 13  2021 - 13
# 1 2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 - 13  2021 - 13
# 2 2021-04-02 05:11:03+00:00     4.0     NaN  2021-04-02  2021 - 13  2021 - 13
# 3 2021-04-02 03:33:24+00:00     5.0     NaN  2021-04-02  2021 - 13  2021 - 13
# 4 2021-04-02 03:31:49+00:00     4.5     NaN  2021-04-02  2021 - 13  2021 - 13

# %%
mon_average_crs = data.groupby(['Month','Course Name']).mean().unstack() # unstack is used for better presentation of the data 
mon_average_crs
mon_average_crs[:20]
# Out:
#                                                               Rating  \
# Course Name 100 Python Exercises I: Evaluate and Improve Your Skills
# Month
# 2018 - 00                                             4.583333
# 2018 - 01                                             4.107143
# 2018 - 02                                             4.166667
# 2018 - 03                                             4.083333
# 2018 - 04                                             4.562500
# 2018 - 05                                             4.500000
# 2018 - 06                                             4.312500
# 2018 - 07                                             4.500000
# 2018 - 08                                             4.192308
# 2018 - 09                                             4.555556
# 2018 - 10                                             4.500000
# 2018 - 11                                             4.375000
# 2018 - 12                                             4.555556
# ...

# %% [markdown]
# ### What day are the people happiest

# %%
data['Weekday'] = data['Timestamp'].dt.strftime('%A')
data
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day       Week  \
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 - 13
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 - 13
# ...

# %%
weekday_aver = data.groupby(['Weekday']).count()
weekday_aver
# Out:
#            Course Name  Timestamp  Rating  Comment   Day  Week  Month
# Weekday
# Friday            6050       6050    6050      964  6050  6050   6050
# Monday            6918       6918    6918      984  6918  6918   6918
# Saturday          5542       5542    5542      903  5542  5542   5542
# Sunday            5673       5673    5673      873  5673  5673   5673
# Thursday          6745       6745    6745      974  6745  6745   6745
# Tuesday           7180       7180    7180     1018  7180  7180   7180
# Wednesday         6892       6892    6892     1083  6892  6892   6892

# %%
weekday_aver = data.groupby(['Weekday']).mean()
weekday_aver
plt.plot(weekday_aver.index, weekday_aver['Rating'])

# %%
data['DayNum'] = data['Timestamp'].dt.strftime('%w') ##this %w is based on the google search 
weekday_aver = data.groupby(['Weekday','DayNum']).mean()
weekday_aver = weekday_aver.sort_values('DayNum')
weekday_aver.index
plt.plot(weekday_aver.index.get_level_values(0), weekday_aver['Rating']) # Here Index is having 2 set of values, we are asking the index to get the first level values ie: Names 
plt.plot(weekday_aver.index.get_level_values(1), weekday_aver['Rating'])

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '_IoffContext',
#  '_IonContext',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_code_objs',
# ...

# %%
share = data.groupby(['Course Name'])['Rating'].count()
share
# Out:
# Course Name
# 100 Python Exercises I: Evaluate and Improve Your Skills       1593
# 100 Python Exercises II: Evaluate and Improve Your Skills       280
# Data Processing with Python                                     868
# Interactive Data Visualization with Python and Bokeh            767
# Learn GIS in One Hour                                           499
# Python for Beginners with Examples                             4821
# The Complete Python Course: Build 10 Professional OOP Apps      470
# The Python Mega Course: Build 10 Real World Applications      35702
# Name: Rating, dtype: int64

# %%
plt.pie(share, labels = share.index) # Pie chart implementation
# Out:
# ([<matplotlib.patches.Wedge at 0x15f41a4da00>,
# ...
#  [Text(1.0932045021416132, 0.12208159770132226, '100 Python Exercises I: Evaluate and Improve Your Skills'),
#   Text(1.0679539537181753, 0.26357987923534204, '100 Python Exercises II: Evaluate and Improve Your Skills'),
#   Text(1.0434237552357248, 0.34823392570193146, 'Data Processing with Python'),
#   Text(0.9969710234481678, 0.46481047579063145, 'Interactive Data Visualization with Python and Bokeh'),
#   Text(0.9520514707070057, 0.5509972750609822, 'Learn GIS in One Hour'),
#   Text(0.6871674297354247, 0.858953388438983, 'Python for Beginners with Examples'),
#   Text(0.3307031314068022, 1.0491117380325774, 'The Complete Python Course: Build 10 Professional OOP Apps'),
#   Text(-0.8762757995015485, -0.6649366309716455, 'The Python Mega Course: Build 10 Real World Applications')])
